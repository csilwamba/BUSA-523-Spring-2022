# %%
# pip install matplotlib
# import matplotlib.pyplot

import matplotlib.pyplot as plt
#plt.style.use("dark_background")
#%matplotlib notebook

import pandas as pd

import numpy as np

# %%
# a) Histogram

# Import Data
data = pd.read_csv("births.csv", header = 0, index_col = 0)
histdata = data.dropna()
histdata
# Out:
#           Births
# Date
# 1/1/59      35.0
# 1/3/59      30.0
# 1/4/59      31.0
# 1/6/59      29.0
# 1/7/59      45.0
# ...          ...
# 12/27/59    37.0
# 12/28/59    52.0
# 12/29/59    48.0
# 12/30/59    55.0
# 12/31/59    50.0
#
# [361 rows x 1 columns]

# %%
histdata.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# b) Bar Chart

# Importing an excel file (sals.xls)
df = pd.read_excel("C:\DataFiles\sales.xls")
df
df["Apple Sales (millions)"].plot(kind = "bar")
#bardata.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# c) Line Chart

# Importing an excel file (sals.xls)
lndf = pd.read_excel("C:\DataFiles\sales.xls", header = 0, index_col = 0)
lndf

lndf.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
# d) Area Chart
lndf
lndf.plot.area()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
# e) Scatter Plot of Sales vs Total Sales after Tax
lndf['Total_Sales'] = lndf["Apple Sales (millions)"]*1.05
lndf
lndf.plot.scatter(x = "Apple Sales (millions)", y = "Total_Sales")
# Out:
# <AxesSubplot:xlabel='Apple Sales (millions)', ylabel='Total_Sales'>

# %%
# Prof. I found the data.csv file at the last minute so I am doing another scatterplot
# e) Part 2
# Importing an excel file (sals.xls)
df2 = pd.read_csv("C:\DataFiles\data.csv")
df2
# Plot CPI vs Unemploment
df2.plot.scatter(x = "CPI", y = "Unemployment")
# Out:
# <AxesSubplot:xlabel='CPI', ylabel='Unemployment'>
