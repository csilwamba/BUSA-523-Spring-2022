# %%
# Question 1
# Write a program which randomly selects a number between 1 and 20. 
#The user is then given 5 chances to guess the number correctly to win.

import random

number = random.randint(1, 20)
guess = 0
print("You have 5 attempts to correctly guess a number between 1 and 20.")
while True:
    guess += 1
    print("Attempt ", guess, end=": ")
    guess = int(input())
    if guess == number:
        print("You win")
        break
    if guess == 5:
        print("You lose")
        break

# Question 2
# Make the following changes to the above program.
    # After each guess, print if the next guess should be lower or higher.
    # For example, if the computer select is 10 and the user input is 6, print guess a higher vale

import random

number = random.randint(1, 20)
guess = 0
print("You have 5 attempts to correctly guess a number between 1 and 20.")
while True:
    guess += 1
    print("Attempt ", guess, end=": ")
    guess = int(input())
    if guess < number:
        print("Next Guess should be higher")
    if guess > number:
        print("Next Guess should be lower")
    if guess == number:
        print("You win")
        break
    if guess == 5:
        print("You lose")
        break
        

# Question 3
# Write a programm for "Rock-Paper-Scissors-Lizard-Spock"

import random

print("Enter the integer corresponding to your move: \n 1. Rock \n 2. Paper \n 3. Scissors \n 4. Lizard \n 5. Spock")

user_input = int(input())
#while user_input> 5 or user_input< 1:

number = random.randint(1,5)
if number == 1:
    computer = "Rock"
elif number == 2:
    computer = "Paper"
elif number == 3:
    computer = "Scissors"
elif number == 4:
    computer = "Lizard"
elif number == 5:
    computer = "Spock"
    
    
    user_input = int(input("Re-Enter your choice: "))
computer_input = random.randint(1, 5)

print("Your move: ", user_input)
print("Computer's move: ", computer_input)

if user_input == computer_input:
    print("It's a Tie!")
elif user_input == 1 and (computer_input == 2 or computer_input == 5):
    print("You lose")
elif user_input == 1 and (computer_input == 3 or computer_input == 4):
    print("You Won")
elif user_input == 2 and (computer_input == 3 or computer_input == 4):
    print("You lose")
elif user_input == 2 and (computer_input == 1 or computer_input == 5):
    print("You Won")
elif user_input == 3 and (computer_input == 1 or computer_input == 5):
    print("You lose")
elif user_input == 3 and (computer_input == 2 or computer_input == 4):
    print("You Won")
elif user_input == 4 and (computer_input == 1 or computer_input == 3):
    print("You lose")
elif user_input == 4 and (computer_input == 2 or computer_input == 5):
    print("You Won")
elif user_input == 5 and (computer_input == 2 or computer_input == 4):
    print("You lose")
else:
    print("Invalid Entry")
# Out:
# You have 5 attempts to correctly guess a number between 1 and 20.
# Attempt  1:
